# %%
# Importing libraries
import pandas as pd
import numpy as np
import re

# %%
# Read csv file into a pandas dataframe
df = pd.read_csv('/Users/Shiva/Documents/GitHub/product3team9/data/raw/housing_data.csv')

# %%
# Take a look at the first few rows
df.head(10)
# Out:
#    globalId publicatieDatum postcode  koopPrijs  \
# 0   4388064      2018-07-31   1774PG   139000.0
# 1   4388200      2018-09-24   7481LK   209000.0
# 2   4399344      2018-08-02   1068MS   267500.0
# 3   4400638      2018-08-04   5628EN   349000.0
# 4   4401765      2018-08-05   7731TV   495000.0
# 5   4401831      2018-08-06   5971CR   162500.0
# 6   4402098      2018-08-06   9571BM   217500.0
# 7   4406997      2018-08-12   1031KA   655000.0
# 8   4407331      2018-08-12   9076BK   180000.0
# 9   4417043      2018-09-08   4465AL   495000.0
#
#                                volledigeOmschrijving  \
# 0  Ruimte, vrijheid, en altijd het water en de we...
# 1  Verrassend ruime tussenwoning nabij het centru...
# 2  - ENGLISH TRANSLATION - \n\nOn the 21st of Sep...
# 3  Wonen in een zeer royaal bemeten geschakelde 2...
# 4  Landgoed Junne is een eeuwenoud landgoed en li...
# 5  In een rustige wijk, op korte afstand van het ...
# 6  In landelijke woonomgeving en aan de doorgaand...
# ...

# %%
df['construction_year']=df['bouwjaar'].str.extract(r'([0-9]{4})')
df.head(10)
# Out:
#    globalId publicatieDatum postcode  koopPrijs  \
# 0   4388064      2018-07-31   1774PG   139000.0
# 1   4388200      2018-09-24   7481LK   209000.0
# 2   4399344      2018-08-02   1068MS   267500.0
# 3   4400638      2018-08-04   5628EN   349000.0
# 4   4401765      2018-08-05   7731TV   495000.0
# 5   4401831      2018-08-06   5971CR   162500.0
# 6   4402098      2018-08-06   9571BM   217500.0
# 7   4406997      2018-08-12   1031KA   655000.0
# 8   4407331      2018-08-12   9076BK   180000.0
# 9   4417043      2018-09-08   4465AL   495000.0
#
#                                volledigeOmschrijving  \
# 0  Ruimte, vrijheid, en altijd het water en de we...
# 1  Verrassend ruime tussenwoning nabij het centru...
# 2  - ENGLISH TRANSLATION - \n\nOn the 21st of Sep...
# 3  Wonen in een zeer royaal bemeten geschakelde 2...
# 4  Landgoed Junne is een eeuwenoud landgoed en li...
# 5  In een rustige wijk, op korte afstand van het ...
# 6  In landelijke woonomgeving en aan de doorgaand...
# ...

# %%
df = df.drop(df.columns[[7]], axis=1)
df.head(10)
# Out:
#    globalId publicatieDatum postcode  koopPrijs  \
# 0   4388064      2018-07-31   1774PG   139000.0
# 1   4388200      2018-09-24   7481LK   209000.0
# 2   4399344      2018-08-02   1068MS   267500.0
# 3   4400638      2018-08-04   5628EN   349000.0
# 4   4401765      2018-08-05   7731TV   495000.0
# 5   4401831      2018-08-06   5971CR   162500.0
# 6   4402098      2018-08-06   9571BM   217500.0
# 7   4406997      2018-08-12   1031KA   655000.0
# 8   4407331      2018-08-12   9076BK   180000.0
# 9   4417043      2018-09-08   4465AL   495000.0
#
#                                volledigeOmschrijving  \
# 0  Ruimte, vrijheid, en altijd het water en de we...
# 1  Verrassend ruime tussenwoning nabij het centru...
# 2  - ENGLISH TRANSLATION - \n\nOn the 21st of Sep...
# 3  Wonen in een zeer royaal bemeten geschakelde 2...
# 4  Landgoed Junne is een eeuwenoud landgoed en li...
# 5  In een rustige wijk, op korte afstand van het ...
# 6  In landelijke woonomgeving en aan de doorgaand...
# ...
