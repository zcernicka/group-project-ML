# %% [markdown]
# # Neural Network for Regression
# This code blends the best of 2 tutorials: https://towardsdatascience.com/deep-neural-networks-for-regression-problems-81321897ca33 and https://www.tensorflow.org/tutorials/keras/regression

# %%
# If error [No module named 'sklearn'], in terminal: conda install -c conda-forge scikit-learn
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error 
# %matplotlib notebook
from matplotlib import pyplot as plt
import seaborn as sb
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings 
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)
# pip install git+https://github.com/tensorflow/docs
import tensorflow as tf
import tensorflow_docs as tfdocs
import tensorflow_docs.plots
import tensorflow_docs.modeling
# Libraries and options
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten

# %% [markdown]
# # 1. Data Preprocessing
# Data: https://www.kaggle.com/c/house-prices-advanced-regression-techniques/data

# %%
# Load data
gt = pd.read_csv('train.csv')
gt.describe()

#!# If opening teh funda file bugs because of special characters:
# Open the file with sublime. Open menu Find > Replace. 
# On the bottom left of the screen, click on the button for regular expression (it's a dot and a star .* )
# Run thi sregular expression, and replace with a space 
# [^A-Za-z0-9-,;()_ "'\.\-\n\r\t]
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000  ...
# 25%       5.000000  1954.000000   1967.000000     0.000000     0.000000  ...
# 50%       5.000000  1973.000000   1994.000000     0.000000   383.500000  ...
# 75%       6.000000  2000.000000   2004.000000   166.000000   712.250000  ...
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000  ...
#
#         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean     94.244521    46.660274      21.954110     3.409589    15.060959
# std     125.338794    66.256028      61.119149    29.317331    55.757415
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    25.000000       0.000000     0.000000     0.000000
# 75%     168.000000    68.000000       0.000000     0.000000     0.000000
# max     857.000000   547.000000     552.000000   508.000000   480.000000
#
#           PoolArea       MiscVal       MoSold       YrSold      SalePrice
# count  1460.000000   1460.000000  1460.000000  1460.000000    1460.000000
# mean      2.758904     43.489041     6.321918  2007.815753  180921.195890
# std      40.177307    496.123024     2.703626     1.328095   79442.502883
# min       0.000000      0.000000     1.000000  2006.000000   34900.000000
# 25%       0.000000      0.000000     5.000000  2007.000000  129975.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  163000.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  214000.000000
# max     738.000000  15500.000000    12.000000  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %%
# Number of rows & columns
gt.shape
# Out:
# (1460, 216)

# %% [markdown]
# ### Exclude data points with missing values

# %%
# Exclude columns containing missing values
def get_cols_with_no_nans(df):
    cols_with_no_nans = []
    for col in df.columns:
        if not df[col].isnull().any():
            cols_with_no_nans.append(col)
    return cols_with_no_nans

cols_no_nans = get_cols_with_no_nans(gt)
gt = gt[cols_no_nans]
gt.describe()
# Out:
#                 Id   MSSubClass        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean    730.500000    56.897260   10516.828082     6.099315     5.575342
# std     421.610009    42.300571    9981.264932     1.382997     1.112799
# min       1.000000    20.000000    1300.000000     1.000000     1.000000
# 25%     365.750000    20.000000    7553.500000     5.000000     5.000000
# 50%     730.500000    50.000000    9478.500000     6.000000     5.000000
# 75%    1095.250000    70.000000   11601.500000     7.000000     6.000000
# max    1460.000000   190.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   BsmtFinSF1   BsmtFinSF2    BsmtUnfSF  ...  \
# count  1460.000000   1460.000000  1460.000000  1460.000000  1460.000000  ...
# mean   1971.267808   1984.865753   443.639726    46.549315   567.240411  ...
# std      30.202904     20.645407   456.098091   161.319273   441.866955  ...
# min    1872.000000   1950.000000     0.000000     0.000000     0.000000  ...
# 25%    1954.000000   1967.000000     0.000000     0.000000   223.000000  ...
# 50%    1973.000000   1994.000000   383.500000     0.000000   477.500000  ...
# 75%    2000.000000   2004.000000   712.250000     0.000000   808.000000  ...
# max    2010.000000   2010.000000  5644.000000  1474.000000  2336.000000  ...
#
#         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean     94.244521    46.660274      21.954110     3.409589    15.060959
# std     125.338794    66.256028      61.119149    29.317331    55.757415
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    25.000000       0.000000     0.000000     0.000000
# 75%     168.000000    68.000000       0.000000     0.000000     0.000000
# max     857.000000   547.000000     552.000000   508.000000   480.000000
#
#           PoolArea       MiscVal       MoSold       YrSold      SalePrice
# count  1460.000000   1460.000000  1460.000000  1460.000000    1460.000000
# mean      2.758904     43.489041     6.321918  2007.815753  180921.195890
# std      40.177307    496.123024     2.703626     1.328095   79442.502883
# min       0.000000      0.000000     1.000000  2006.000000   34900.000000
# 25%       0.000000      0.000000     5.000000  2007.000000  129975.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  163000.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  214000.000000
# max     738.000000  15500.000000    12.000000  2010.000000  755000.000000
#
# [8 rows x 35 columns]

# %% [markdown]
# ### Clean data frame

# %%
# Rename & extract the variable to predict
target = gt.SalePrice
gt.drop(['SalePrice'],axis = 1 , inplace = True)
gt['Target'] = target

# Drop column ID
gt.drop(['Id'],axis = 1 , inplace = True)

# Overview of feature distribution
gt.hist(figsize = (10,8))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ### Explore correlations

# %%
# Compute correlation
correlation_matrix = gt.corr()

# Open figure container
fig = plt.figure(figsize = (8,8))
# Make color heatmap (library seaborn)
sb.heatmap(correlation_matrix, vmax = 0.8, vmin=-0.8, square = True, cmap='RdBu_r')
# Display plot
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ### One-hot-encoding of categorical variables

# %%
# Function for the one-hot encoding
def oneHotEncode(df,colNames):
    for col in colNames:
        if( df[col].dtype == np.dtype('object')):
            dummies = pd.get_dummies(df[col],prefix=col)
            df = pd.concat([df,dummies],axis=1)

            #drop the encoded column
            df.drop([col],axis = 1 , inplace=True)
    return df

# Get index of categorical columns 
cat_cols = gt.select_dtypes(include=['object'])
cat_cols = cat_cols.columns

# Transform data
print('There were {} columns before encoding categorical features'.format(gt.shape[1]))
gt = oneHotEncode(gt, cat_cols)
print('There are {} columns after encoding categorical features'.format(gt.shape[1]))
# Out:
# There were 61 columns before encoding categorical features
# There are 216 columns after encoding categorical features

# %% [markdown]
# ### Split data into train & test

# %%
n_train = round(gt.shape[0] * 0.6)
train = gt[:n_train]
test = gt[n_train:]

target = train['Target']
train.drop(['Target'], axis = 1, inplace = True)

truth = test['Target']
test.drop(['Target'], axis = 1, inplace = True)

# %% [markdown]
# # 2. Build Neural Network

# %%
# Initiate a sequential model (i.e., no recurrence)
NN_model = Sequential()

# Make the first layer
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = train.shape[1], activation='relu'))

# Make hidden layers
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# Make the output layer
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network
NN_model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])
NN_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               27648
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 126,721
# Trainable params: 126,721
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Checkpoint callback
# A backup system that saves the models learned at each epoch.
# It saves only the models that are better than the previous models.
#
# A file is made for each new model, containing the weights & biases of each neuron. Any of these files can be loaded to instantiate the corresponding network.

# %%
# Define how to name the files
checkpoint_name = 'Weights-{epoch:03d}--{val_loss:.5f}.hdf5' 
# Instantiate the checkpoint system
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]

# %% [markdown]
# ### Train the neural network

# %%
history = NN_model.fit(train, target, epochs=100, 
             # No. of randomly sampled data points used to compute the errors at each epoch (avoid overfitting)
             batch_size=32, 
             # Size of validation set for cross-validation
             validation_split = 0.2, 
             # Link to checkpoint system, to check teh best model previously built
             callbacks=callbacks_list)
# Out:
# Train on 700 samples, validate on 176 samples
# Epoch 1/100
#  32/700 [>.............................] - ETA: 5s - loss: 35472637952.0000 - mean_absolute_error: 179352.1875
# Epoch 00001: val_loss improved from inf to 31822081861.81818, saving model to Weights-001--31822081861.81818.hdf5
# 700/700 [==============================] - 0s 618us/sample - loss: 38442537802.6057 - mean_absolute_error: 178503.4531 - val_loss: 31822081861.8182 - val_mean_absolute_error: 162416.6719
# Epoch 2/100
#  32/700 [>.............................] - ETA: 0s - loss: 49331843072.0000 - mean_absolute_error: 182491.9688
# Epoch 00002: val_loss improved from 31822081861.81818 to 7853151837.09091, saving model to Weights-002--7853151837.09091.hdf5
# 700/700 [==============================] - 0s 125us/sample - loss: 22849001246.7200 - mean_absolute_error: 110857.5625 - val_loss: 7853151837.0909 - val_mean_absolute_error: 57406.5625
# Epoch 3/100
#  32/700 [>.............................] - ETA: 0s - loss: 5871048704.0000 - mean_absolute_error: 50696.1094
# Epoch 00003: val_loss improved from 7853151837.09091 to 4872776704.00000, saving model to Weights-003--4872776704.00000.hdf5
# 700/700 [==============================] - 0s 123us/sample - loss: 9607762104.3200 - mean_absolute_error: 57463.1445 - val_loss: 4872776704.0000 - val_mean_absolute_error: 44873.6406
# Epoch 4/100
# 672/700 [===========================>..] - ETA: 0s - loss: 7084451254.8571 - mean_absolute_error: 48573.2422
# Epoch 00004: val_loss improved from 4872776704.00000 to 4563818007.27273, saving model to Weights-004--4563818007.27273.hdf5
# 700/700 [==============================] - 0s 139us/sample - loss: 6984897158.5829 - mean_absolute_error: 48654.8633 - val_loss: 4563818007.2727 - val_mean_absolute_error: 43966.8438
# Epoch 5/100
#  32/700 [>.............................] - ETA: 0s - loss: 2504974080.0000 - mean_absolute_error: 37771.6172
# Epoch 00005: val_loss improved from 4563818007.27273 to 3332734778.18182, saving model to Weights-005--3332734778.18182.hdf5
# 700/700 [==============================] - 0s 148us/sample - loss: 5191760815.5429 - mean_absolute_error: 45309.2344 - val_loss: 3332734778.1818 - val_mean_absolute_error: 40265.0898
# Epoch 6/100
#  32/700 [>.............................] - ETA: 0s - loss: 1623292800.0000 - mean_absolute_error: 33304.2188
# Epoch 00006: val_loss improved from 3332734778.18182 to 3075017890.90909, saving model to Weights-006--3075017890.90909.hdf5
# 700/700 [==============================] - 0s 129us/sample - loss: 4169253573.4857 - mean_absolute_error: 43042.7695 - val_loss: 3075017890.9091 - val_mean_absolute_error: 39586.4688
# Epoch 7/100
#  32/700 [>.............................] - ETA: 0s - loss: 2283265280.0000 - mean_absolute_error: 38318.7969
# Epoch 00007: val_loss improved from 3075017890.90909 to 3002834629.81818, saving model to Weights-007--3002834629.81818.hdf5
# 700/700 [==============================] - 0s 130us/sample - loss: 3719256375.5886 - mean_absolute_error: 42960.5352 - val_loss: 3002834629.8182 - val_mean_absolute_error: 37348.7344
# Epoch 8/100
#  32/700 [>.............................] - ETA: 0s - loss: 2763026176.0000 - mean_absolute_error: 41069.2461
# Epoch 00008: val_loss improved from 3002834629.81818 to 2781516893.09091, saving model to Weights-008--2781516893.09091.hdf5
# 700/700 [==============================] - 0s 129us/sample - loss: 3448227441.3714 - mean_absolute_error: 40953.8789 - val_loss: 2781516893.0909 - val_mean_absolute_error: 38012.2852
# Epoch 9/100
#  32/700 [>.............................] - ETA: 0s - loss: 7962904576.0000 - mean_absolute_error: 55336.4688
# Epoch 00009: val_loss improved from 2781516893.09091 to 2746986624.00000, saving model to Weights-009--2746986624.00000.hdf5
# 700/700 [==============================] - 0s 133us/sample - loss: 3176068395.8857 - mean_absolute_error: 40686.6719 - val_loss: 2746986624.0000 - val_mean_absolute_error: 35033.8359
# Epoch 10/100
#  32/700 [>.............................] - ETA: 0s - loss: 5365446656.0000 - mean_absolute_error: 50262.1914
# Epoch 00010: val_loss improved from 2746986624.00000 to 2554132410.18182, saving model to Weights-010--2554132410.18182.hdf5
# 700/700 [==============================] - 0s 125us/sample - loss: 3030599914.0571 - mean_absolute_error: 38989.9531 - val_loss: 2554132410.1818 - val_mean_absolute_error: 34414.9141
# Epoch 11/100
#  32/700 [>.............................] - ETA: 0s - loss: 2211915008.0000 - mean_absolute_error: 40634.2656
# Epoch 00011: val_loss improved from 2554132410.18182 to 2410994164.36364, saving model to Weights-011--2410994164.36364.hdf5
# 700/700 [==============================] - 0s 144us/sample - loss: 2820579619.1086 - mean_absolute_error: 37590.4766 - val_loss: 2410994164.3636 - val_mean_absolute_error: 34278.2227
# Epoch 12/100
#  32/700 [>.............................] - ETA: 0s - loss: 1985555072.0000 - mean_absolute_error: 34463.5469
# Epoch 00012: val_loss improved from 2410994164.36364 to 2346960512.00000, saving model to Weights-012--2346960512.00000.hdf5
# 700/700 [==============================] - 0s 133us/sample - loss: 2686716448.1829 - mean_absolute_error: 36821.4883 - val_loss: 2346960512.0000 - val_mean_absolute_error: 31857.8555
# Epoch 13/100
#  32/700 [>.............................] - ETA: 0s - loss: 2477703424.0000 - mean_absolute_error: 39194.5742
# Epoch 00013: val_loss improved from 2346960512.00000 to 2198602368.00000, saving model to Weights-013--2198602368.00000.hdf5
# 700/700 [==============================] - 0s 145us/sample - loss: 2536505844.2971 - mean_absolute_error: 35268.3398 - val_loss: 2198602368.0000 - val_mean_absolute_error: 30849.8008
# Epoch 14/100
#  32/700 [>.............................] - ETA: 0s - loss: 1966418176.0000 - mean_absolute_error: 29510.1797
# Epoch 00014: val_loss improved from 2198602368.00000 to 2110898222.54545, saving model to Weights-014--2110898222.54545.hdf5
# 700/700 [==============================] - 0s 169us/sample - loss: 2370389866.7886 - mean_absolute_error: 34308.9844 - val_loss: 2110898222.5455 - val_mean_absolute_error: 29720.9082
# Epoch 15/100
#  32/700 [>.............................] - ETA: 0s - loss: 1202948992.0000 - mean_absolute_error: 28589.5898
# Epoch 00015: val_loss improved from 2110898222.54545 to 2053451973.81818, saving model to Weights-015--2053451973.81818.hdf5
# 700/700 [==============================] - 0s 147us/sample - loss: 2298200867.1086 - mean_absolute_error: 32733.8516 - val_loss: 2053451973.8182 - val_mean_absolute_error: 29001.2695
# Epoch 16/100
#  32/700 [>.............................] - ETA: 0s - loss: 1576669952.0000 - mean_absolute_error: 28003.4922
# Epoch 00016: val_loss improved from 2053451973.81818 to 1893698234.18182, saving model to Weights-016--1893698234.18182.hdf5
# 700/700 [==============================] - 0s 163us/sample - loss: 2129790453.0286 - mean_absolute_error: 31604.2637 - val_loss: 1893698234.1818 - val_mean_absolute_error: 27873.5430
# Epoch 17/100
#  32/700 [>.............................] - ETA: 0s - loss: 1162855040.0000 - mean_absolute_error: 23340.4336
# Epoch 00017: val_loss did not improve from 1893698234.18182
# 700/700 [==============================] - 0s 92us/sample - loss: 2091354583.0400 - mean_absolute_error: 30506.1055 - val_loss: 1922114013.0909 - val_mean_absolute_error: 28135.0957
# Epoch 18/100
#  32/700 [>.............................] - ETA: 0s - loss: 2270739968.0000 - mean_absolute_error: 33221.1016
# Epoch 00018: val_loss improved from 1893698234.18182 to 1659917288.72727, saving model to Weights-018--1659917288.72727.hdf5
# 700/700 [==============================] - 0s 130us/sample - loss: 1924704898.9257 - mean_absolute_error: 29642.6348 - val_loss: 1659917288.7273 - val_mean_absolute_error: 27282.8379
# Epoch 19/100
#  32/700 [>.............................] - ETA: 0s - loss: 2261939200.0000 - mean_absolute_error: 33137.3867
# Epoch 00019: val_loss improved from 1659917288.72727 to 1574704343.27273, saving model to Weights-019--1574704343.27273.hdf5
# 700/700 [==============================] - 0s 139us/sample - loss: 1872333440.7314 - mean_absolute_error: 28570.3398 - val_loss: 1574704343.2727 - val_mean_absolute_error: 25810.1875
# Epoch 20/100
#  32/700 [>.............................] - ETA: 0s - loss: 1467552512.0000 - mean_absolute_error: 25049.3242
# Epoch 00020: val_loss did not improve from 1574704343.27273
# 700/700 [==============================] - 0s 86us/sample - loss: 1864161640.5943 - mean_absolute_error: 28624.3457 - val_loss: 1608067072.0000 - val_mean_absolute_error: 25927.8926
# Epoch 21/100
#  32/700 [>.............................] - ETA: 0s - loss: 1400674304.0000 - mean_absolute_error: 27049.5742
# Epoch 00021: val_loss improved from 1574704343.27273 to 1514338437.81818, saving model to Weights-021--1514338437.81818.hdf5
# 700/700 [==============================] - 0s 114us/sample - loss: 1766084147.9314 - mean_absolute_error: 27920.1113 - val_loss: 1514338437.8182 - val_mean_absolute_error: 25282.5742
# Epoch 22/100
#  32/700 [>.............................] - ETA: 0s - loss: 1052761280.0000 - mean_absolute_error: 23420.1953
# Epoch 00022: val_loss improved from 1514338437.81818 to 1469131723.63636, saving model to Weights-022--1469131723.63636.hdf5
# 700/700 [==============================] - 0s 122us/sample - loss: 1782413556.2971 - mean_absolute_error: 27791.8574 - val_loss: 1469131723.6364 - val_mean_absolute_error: 25522.8457
# Epoch 23/100
#  32/700 [>.............................] - ETA: 0s - loss: 1592305920.0000 - mean_absolute_error: 32503.1328
# Epoch 00023: val_loss improved from 1469131723.63636 to 1441663133.09091, saving model to Weights-023--1441663133.09091.hdf5
# 700/700 [==============================] - 0s 111us/sample - loss: 1741797697.0971 - mean_absolute_error: 27632.9551 - val_loss: 1441663133.0909 - val_mean_absolute_error: 25119.3867
# Epoch 24/100
#  32/700 [>.............................] - ETA: 0s - loss: 2975479296.0000 - mean_absolute_error: 35240.9219
# Epoch 00024: val_loss improved from 1441663133.09091 to 1431829207.27273, saving model to Weights-024--1431829207.27273.hdf5
# 700/700 [==============================] - 0s 113us/sample - loss: 1730274235.9771 - mean_absolute_error: 27765.2461 - val_loss: 1431829207.2727 - val_mean_absolute_error: 25086.6953
# Epoch 25/100
#  32/700 [>.............................] - ETA: 0s - loss: 604675392.0000 - mean_absolute_error: 18658.1660
# Epoch 00025: val_loss did not improve from 1431829207.27273
# 700/700 [==============================] - 0s 83us/sample - loss: 1712813316.3886 - mean_absolute_error: 27316.3203 - val_loss: 1448296541.0909 - val_mean_absolute_error: 25273.6113
# Epoch 26/100
#  32/700 [>.............................] - ETA: 0s - loss: 1017785024.0000 - mean_absolute_error: 23327.9219
# Epoch 00026: val_loss did not improve from 1431829207.27273
# 700/700 [==============================] - 0s 67us/sample - loss: 1765197476.5714 - mean_absolute_error: 28667.9258 - val_loss: 1517961181.0909 - val_mean_absolute_error: 26223.5000
# Epoch 27/100
#  32/700 [>.............................] - ETA: 0s - loss: 1583821696.0000 - mean_absolute_error: 27601.7910
# Epoch 00027: val_loss improved from 1431829207.27273 to 1403609792.00000, saving model to Weights-027--1403609792.00000.hdf5
# 700/700 [==============================] - 0s 104us/sample - loss: 1755514499.6571 - mean_absolute_error: 27915.6309 - val_loss: 1403609792.0000 - val_mean_absolute_error: 24985.5703
# Epoch 28/100
#  32/700 [>.............................] - ETA: 0s - loss: 2645812224.0000 - mean_absolute_error: 36237.0078
# Epoch 00028: val_loss did not improve from 1403609792.00000
# 700/700 [==============================] - 0s 89us/sample - loss: 1708044941.5314 - mean_absolute_error: 27351.6113 - val_loss: 1412876869.8182 - val_mean_absolute_error: 25034.2051
# Epoch 29/100
#  32/700 [>.............................] - ETA: 0s - loss: 1017482368.0000 - mean_absolute_error: 23674.0410
# Epoch 00029: val_loss improved from 1403609792.00000 to 1386471575.27273, saving model to Weights-029--1386471575.27273.hdf5
# 700/700 [==============================] - 0s 124us/sample - loss: 1679127805.8057 - mean_absolute_error: 27062.1895 - val_loss: 1386471575.2727 - val_mean_absolute_error: 24806.2734
# Epoch 30/100
#  32/700 [>.............................] - ETA: 0s - loss: 1655422592.0000 - mean_absolute_error: 25728.2520
# Epoch 00030: val_loss did not improve from 1386471575.27273
# 700/700 [==============================] - 0s 85us/sample - loss: 1769756646.7657 - mean_absolute_error: 27782.6309 - val_loss: 1392365079.2727 - val_mean_absolute_error: 25004.5820
# Epoch 31/100
#  32/700 [>.............................] - ETA: 0s - loss: 1140324608.0000 - mean_absolute_error: 23044.0156
# Epoch 00031: val_loss did not improve from 1386471575.27273
# 700/700 [==============================] - 0s 83us/sample - loss: 1682556320.9143 - mean_absolute_error: 26801.0684 - val_loss: 1415654458.1818 - val_mean_absolute_error: 25147.0332
# Epoch 32/100
#  32/700 [>.............................] - ETA: 0s - loss: 1952619776.0000 - mean_absolute_error: 30544.3086
# Epoch 00032: val_loss did not improve from 1386471575.27273
# 700/700 [==============================] - 0s 80us/sample - loss: 1722439255.0400 - mean_absolute_error: 27290.5859 - val_loss: 1438705716.3636 - val_mean_absolute_error: 25897.5625
# Epoch 33/100
#  32/700 [>.............................] - ETA: 0s - loss: 761050688.0000 - mean_absolute_error: 19838.9570
# Epoch 00033: val_loss improved from 1386471575.27273 to 1371154286.54545, saving model to Weights-033--1371154286.54545.hdf5
# 700/700 [==============================] - 0s 138us/sample - loss: 1740247560.7771 - mean_absolute_error: 27533.2773 - val_loss: 1371154286.5455 - val_mean_absolute_error: 24887.8379
# Epoch 34/100
#  32/700 [>.............................] - ETA: 0s - loss: 622118912.0000 - mean_absolute_error: 18821.0586
# Epoch 00034: val_loss did not improve from 1371154286.54545
# 700/700 [==============================] - 0s 78us/sample - loss: 1676856694.1257 - mean_absolute_error: 27159.6172 - val_loss: 1531993431.2727 - val_mean_absolute_error: 26791.2832
# Epoch 35/100
#  32/700 [>.............................] - ETA: 0s - loss: 931479808.0000 - mean_absolute_error: 20306.9102
# Epoch 00035: val_loss did not improve from 1371154286.54545
# 700/700 [==============================] - 0s 76us/sample - loss: 1693987381.3943 - mean_absolute_error: 27474.3281 - val_loss: 1399789597.0909 - val_mean_absolute_error: 24946.9258
# Epoch 36/100
#  32/700 [>.............................] - ETA: 0s - loss: 789690368.0000 - mean_absolute_error: 20879.3945
# Epoch 00036: val_loss did not improve from 1371154286.54545
# 700/700 [==============================] - 0s 77us/sample - loss: 1718913096.4114 - mean_absolute_error: 27235.6484 - val_loss: 1380677568.0000 - val_mean_absolute_error: 24990.4434
# Epoch 37/100
#  32/700 [>.............................] - ETA: 0s - loss: 1701281024.0000 - mean_absolute_error: 31423.8184
# Epoch 00037: val_loss did not improve from 1371154286.54545
# 700/700 [==============================] - 0s 81us/sample - loss: 1667804938.2400 - mean_absolute_error: 26925.3145 - val_loss: 1371660136.7273 - val_mean_absolute_error: 25000.7383
# Epoch 38/100
#  32/700 [>.............................] - ETA: 0s - loss: 707929856.0000 - mean_absolute_error: 20425.0703
# Epoch 00038: val_loss did not improve from 1371154286.54545
# 700/700 [==============================] - 0s 87us/sample - loss: 1683432492.6171 - mean_absolute_error: 27545.4863 - val_loss: 1381070592.0000 - val_mean_absolute_error: 24829.8242
# Epoch 39/100
#  32/700 [>.............................] - ETA: 0s - loss: 819856128.0000 - mean_absolute_error: 22543.7734
# Epoch 00039: val_loss did not improve from 1371154286.54545
# 700/700 [==============================] - 0s 84us/sample - loss: 1643206927.7257 - mean_absolute_error: 26568.3164 - val_loss: 1409723112.7273 - val_mean_absolute_error: 25209.2988
# Epoch 40/100
#  32/700 [>.............................] - ETA: 0s - loss: 925858816.0000 - mean_absolute_error: 22620.0840
# Epoch 00040: val_loss improved from 1371154286.54545 to 1364200203.63636, saving model to Weights-040--1364200203.63636.hdf5
# 700/700 [==============================] - 0s 143us/sample - loss: 1620974050.3771 - mean_absolute_error: 27032.3828 - val_loss: 1364200203.6364 - val_mean_absolute_error: 24932.3809
# Epoch 41/100
# 608/700 [=========================>....] - ETA: 0s - loss: 1606536116.2105 - mean_absolute_error: 26816.2949
# Epoch 00041: val_loss did not improve from 1364200203.63636
# 700/700 [==============================] - 0s 107us/sample - loss: 1625942312.2286 - mean_absolute_error: 27231.8887 - val_loss: 1389569413.8182 - val_mean_absolute_error: 25308.5801
# Epoch 42/100
#  32/700 [>.............................] - ETA: 0s - loss: 1664751104.0000 - mean_absolute_error: 28013.9980
# Epoch 00042: val_loss improved from 1364200203.63636 to 1349876427.63636, saving model to Weights-042--1349876427.63636.hdf5
# 700/700 [==============================] - 0s 133us/sample - loss: 1625870667.3371 - mean_absolute_error: 26599.4863 - val_loss: 1349876427.6364 - val_mean_absolute_error: 24838.7051
# Epoch 43/100
#  32/700 [>.............................] - ETA: 0s - loss: 2370180352.0000 - mean_absolute_error: 35112.0000
# Epoch 00043: val_loss did not improve from 1349876427.63636
# 700/700 [==============================] - 0s 82us/sample - loss: 1625139616.1829 - mean_absolute_error: 26680.5430 - val_loss: 1368725829.8182 - val_mean_absolute_error: 25026.6992
# Epoch 44/100
#  32/700 [>.............................] - ETA: 0s - loss: 1794754432.0000 - mean_absolute_error: 25597.9199
# Epoch 00044: val_loss did not improve from 1349876427.63636
# 700/700 [==============================] - 0s 81us/sample - loss: 1648653228.6171 - mean_absolute_error: 26883.1602 - val_loss: 1352011083.6364 - val_mean_absolute_error: 24820.7109
# Epoch 45/100
#  32/700 [>.............................] - ETA: 0s - loss: 1041768320.0000 - mean_absolute_error: 24063.2539
# Epoch 00045: val_loss did not improve from 1349876427.63636
# 700/700 [==============================] - 0s 82us/sample - loss: 1611646113.6457 - mean_absolute_error: 26520.3379 - val_loss: 1372038807.2727 - val_mean_absolute_error: 25168.5020
# Epoch 46/100
#  32/700 [>.............................] - ETA: 0s - loss: 2553967104.0000 - mean_absolute_error: 32834.9453
# Epoch 00046: val_loss improved from 1349876427.63636 to 1338775185.45455, saving model to Weights-046--1338775185.45455.hdf5
# 700/700 [==============================] - 0s 126us/sample - loss: 1712940187.0629 - mean_absolute_error: 27303.6152 - val_loss: 1338775185.4545 - val_mean_absolute_error: 24797.7500
# Epoch 47/100
#  32/700 [>.............................] - ETA: 0s - loss: 964404224.0000 - mean_absolute_error: 23026.3594
# Epoch 00047: val_loss did not improve from 1338775185.45455
# 700/700 [==============================] - 0s 77us/sample - loss: 1661337704.9600 - mean_absolute_error: 26971.8477 - val_loss: 1469935371.6364 - val_mean_absolute_error: 26307.9551
# Epoch 48/100
#  32/700 [>.............................] - ETA: 0s - loss: 759722368.0000 - mean_absolute_error: 21089.8359
# Epoch 00048: val_loss did not improve from 1338775185.45455
# 700/700 [==============================] - 0s 70us/sample - loss: 1651840696.3200 - mean_absolute_error: 26783.3340 - val_loss: 1458935266.9091 - val_mean_absolute_error: 26193.3691
# Epoch 49/100
#  32/700 [>.............................] - ETA: 0s - loss: 2195336192.0000 - mean_absolute_error: 29662.6953
# Epoch 00049: val_loss did not improve from 1338775185.45455
# 700/700 [==============================] - 0s 69us/sample - loss: 1632486970.1486 - mean_absolute_error: 26478.9551 - val_loss: 1366595456.0000 - val_mean_absolute_error: 24872.5254
# Epoch 50/100
#  32/700 [>.............................] - ETA: 0s - loss: 1701720576.0000 - mean_absolute_error: 28141.5176
# Epoch 00050: val_loss did not improve from 1338775185.45455
# 700/700 [==============================] - 0s 70us/sample - loss: 1604523259.6114 - mean_absolute_error: 26430.0625 - val_loss: 1348873774.5455 - val_mean_absolute_error: 24781.8555
# Epoch 51/100
#  32/700 [>.............................] - ETA: 0s - loss: 2147914496.0000 - mean_absolute_error: 32226.9922
# Epoch 00051: val_loss did not improve from 1338775185.45455
# 700/700 [==============================] - 0s 70us/sample - loss: 1604735635.3829 - mean_absolute_error: 26392.3594 - val_loss: 1364056529.4545 - val_mean_absolute_error: 24977.1758
# Epoch 52/100
#  32/700 [>.............................] - ETA: 0s - loss: 1114293120.0000 - mean_absolute_error: 22458.9121
# Epoch 00052: val_loss did not improve from 1338775185.45455
# 700/700 [==============================] - 0s 76us/sample - loss: 1570519499.3371 - mean_absolute_error: 26289.8164 - val_loss: 1347440285.0909 - val_mean_absolute_error: 24878.5312
# Epoch 53/100
#  32/700 [>.............................] - ETA: 0s - loss: 1027540608.0000 - mean_absolute_error: 24974.2148
# Epoch 00053: val_loss did not improve from 1338775185.45455
# 700/700 [==============================] - 0s 69us/sample - loss: 1573570141.6229 - mean_absolute_error: 26045.0664 - val_loss: 1340152157.0909 - val_mean_absolute_error: 24796.5332
# Epoch 54/100
#  32/700 [>.............................] - ETA: 0s - loss: 1073272832.0000 - mean_absolute_error: 25226.0391
# Epoch 00054: val_loss did not improve from 1338775185.45455
# 700/700 [==============================] - 0s 71us/sample - loss: 1581949860.2057 - mean_absolute_error: 26346.6660 - val_loss: 1632071249.4545 - val_mean_absolute_error: 28377.7695
# Epoch 55/100
#  32/700 [>.............................] - ETA: 0s - loss: 1846532224.0000 - mean_absolute_error: 32476.9336
# Epoch 00055: val_loss did not improve from 1338775185.45455
# 700/700 [==============================] - 0s 69us/sample - loss: 1640105874.2857 - mean_absolute_error: 27067.7949 - val_loss: 1590136023.2727 - val_mean_absolute_error: 27593.3867
# Epoch 56/100
#  32/700 [>.............................] - ETA: 0s - loss: 2715720448.0000 - mean_absolute_error: 31458.1660
# Epoch 00056: val_loss did not improve from 1338775185.45455
# 700/700 [==============================] - 0s 70us/sample - loss: 1602411906.5600 - mean_absolute_error: 26342.5664 - val_loss: 1350327028.3636 - val_mean_absolute_error: 24922.0293
# Epoch 57/100
#  32/700 [>.............................] - ETA: 0s - loss: 2584698880.0000 - mean_absolute_error: 35139.2578
# Epoch 00057: val_loss did not improve from 1338775185.45455
# 700/700 [==============================] - 0s 71us/sample - loss: 1584781702.5829 - mean_absolute_error: 26281.5000 - val_loss: 1387733760.0000 - val_mean_absolute_error: 25337.9062
# Epoch 58/100
#  32/700 [>.............................] - ETA: 0s - loss: 634225984.0000 - mean_absolute_error: 19816.6523
# Epoch 00058: val_loss did not improve from 1338775185.45455
# 700/700 [==============================] - 0s 71us/sample - loss: 1558517946.5143 - mean_absolute_error: 26145.1777 - val_loss: 1343325463.2727 - val_mean_absolute_error: 24924.8301
# Epoch 59/100
#  32/700 [>.............................] - ETA: 0s - loss: 1186434560.0000 - mean_absolute_error: 24987.3633
# Epoch 00059: val_loss did not improve from 1338775185.45455
# 700/700 [==============================] - 0s 75us/sample - loss: 1553624730.3314 - mean_absolute_error: 25793.1914 - val_loss: 1384755025.4545 - val_mean_absolute_error: 25459.8945
# Epoch 60/100
#  32/700 [>.............................] - ETA: 0s - loss: 5547792384.0000 - mean_absolute_error: 33975.0000
# Epoch 00060: val_loss did not improve from 1338775185.45455
# 700/700 [==============================] - 0s 80us/sample - loss: 1649151045.4857 - mean_absolute_error: 27038.8223 - val_loss: 1559866897.4545 - val_mean_absolute_error: 27329.4121
# Epoch 61/100
#  32/700 [>.............................] - ETA: 0s - loss: 1807115008.0000 - mean_absolute_error: 29033.0684
# Epoch 00061: val_loss did not improve from 1338775185.45455
# 700/700 [==============================] - 0s 79us/sample - loss: 1554325793.6457 - mean_absolute_error: 25994.5391 - val_loss: 1429450804.3636 - val_mean_absolute_error: 26073.2695
# Epoch 62/100
#  32/700 [>.............................] - ETA: 0s - loss: 1281952128.0000 - mean_absolute_error: 28801.4102
# Epoch 00062: val_loss improved from 1338775185.45455 to 1331360640.00000, saving model to Weights-062--1331360640.00000.hdf5
# 700/700 [==============================] - 0s 128us/sample - loss: 1580399512.8686 - mean_absolute_error: 26172.5137 - val_loss: 1331360640.0000 - val_mean_absolute_error: 24742.9824
# Epoch 63/100
#  32/700 [>.............................] - ETA: 0s - loss: 6491301888.0000 - mean_absolute_error: 40606.3477
# Epoch 00063: val_loss did not improve from 1331360640.00000
# 700/700 [==============================] - 0s 82us/sample - loss: 1571306130.2857 - mean_absolute_error: 26172.8887 - val_loss: 1333826554.1818 - val_mean_absolute_error: 24748.1582
# Epoch 64/100
#  32/700 [>.............................] - ETA: 0s - loss: 2222128128.0000 - mean_absolute_error: 24900.9492
# Epoch 00064: val_loss improved from 1331360640.00000 to 1316913163.63636, saving model to Weights-064--1316913163.63636.hdf5
# 700/700 [==============================] - 0s 128us/sample - loss: 1574523267.6571 - mean_absolute_error: 26059.7637 - val_loss: 1316913163.6364 - val_mean_absolute_error: 24713.3516
# Epoch 65/100
#  32/700 [>.............................] - ETA: 0s - loss: 1102179328.0000 - mean_absolute_error: 23871.4727
# Epoch 00065: val_loss did not improve from 1316913163.63636
# 700/700 [==============================] - 0s 71us/sample - loss: 1634844210.4686 - mean_absolute_error: 26663.8828 - val_loss: 1353582801.4545 - val_mean_absolute_error: 25043.9082
# Epoch 66/100
#  32/700 [>.............................] - ETA: 0s - loss: 1750078976.0000 - mean_absolute_error: 28422.4805
# Epoch 00066: val_loss did not improve from 1316913163.63636
# 700/700 [==============================] - 0s 69us/sample - loss: 1580772301.5314 - mean_absolute_error: 26384.5508 - val_loss: 1360790859.6364 - val_mean_absolute_error: 25134.7617
# Epoch 67/100
#  32/700 [>.............................] - ETA: 0s - loss: 994994880.0000 - mean_absolute_error: 23052.2148
# Epoch 00067: val_loss did not improve from 1316913163.63636
# 700/700 [==============================] - 0s 69us/sample - loss: 1601846052.5714 - mean_absolute_error: 26568.4316 - val_loss: 1333426757.8182 - val_mean_absolute_error: 24816.0703
# Epoch 68/100
#  32/700 [>.............................] - ETA: 0s - loss: 1534150656.0000 - mean_absolute_error: 27496.5117
# Epoch 00068: val_loss did not improve from 1316913163.63636
# 700/700 [==============================] - 0s 69us/sample - loss: 1540077565.8057 - mean_absolute_error: 25790.6250 - val_loss: 1444559842.9091 - val_mean_absolute_error: 26203.5430
# Epoch 69/100
#  32/700 [>.............................] - ETA: 0s - loss: 1454021504.0000 - mean_absolute_error: 28968.4043
# Epoch 00069: val_loss did not improve from 1316913163.63636
# 700/700 [==============================] - 0s 71us/sample - loss: 1641555049.3257 - mean_absolute_error: 26671.5430 - val_loss: 1320378856.7273 - val_mean_absolute_error: 24713.7988
# Epoch 70/100
#  32/700 [>.............................] - ETA: 0s - loss: 1309261440.0000 - mean_absolute_error: 27048.4727
# Epoch 00070: val_loss did not improve from 1316913163.63636
# 700/700 [==============================] - 0s 68us/sample - loss: 1644927501.5314 - mean_absolute_error: 26867.1152 - val_loss: 1329793792.0000 - val_mean_absolute_error: 24792.9766
# Epoch 71/100
#  32/700 [>.............................] - ETA: 0s - loss: 940896256.0000 - mean_absolute_error: 22381.8086
# Epoch 00071: val_loss did not improve from 1316913163.63636
# 700/700 [==============================] - 0s 68us/sample - loss: 1523325517.5314 - mean_absolute_error: 25656.0000 - val_loss: 1347012445.0909 - val_mean_absolute_error: 25021.7109
# Epoch 72/100
#  32/700 [>.............................] - ETA: 0s - loss: 694207744.0000 - mean_absolute_error: 19645.3691
# Epoch 00072: val_loss did not improve from 1316913163.63636
# 700/700 [==============================] - 0s 71us/sample - loss: 1515983231.2686 - mean_absolute_error: 25542.2520 - val_loss: 1318171357.0909 - val_mean_absolute_error: 24718.3320
# Epoch 73/100
#  32/700 [>.............................] - ETA: 0s - loss: 1428059392.0000 - mean_absolute_error: 25714.4824
# Epoch 00073: val_loss did not improve from 1316913163.63636
# 700/700 [==============================] - 0s 75us/sample - loss: 1511069049.7829 - mean_absolute_error: 25642.6465 - val_loss: 1374820130.9091 - val_mean_absolute_error: 25356.8867
# Epoch 74/100
#  32/700 [>.............................] - ETA: 0s - loss: 1410828928.0000 - mean_absolute_error: 24076.0195
# Epoch 00074: val_loss did not improve from 1316913163.63636
# 700/700 [==============================] - 0s 79us/sample - loss: 1524225045.9429 - mean_absolute_error: 25891.0605 - val_loss: 1397151144.7273 - val_mean_absolute_error: 25623.7188
# Epoch 75/100
#  32/700 [>.............................] - ETA: 0s - loss: 1313788160.0000 - mean_absolute_error: 25948.1602
# Epoch 00075: val_loss did not improve from 1316913163.63636
# 700/700 [==============================] - 0s 69us/sample - loss: 1536688124.7086 - mean_absolute_error: 25753.5723 - val_loss: 1319165096.7273 - val_mean_absolute_error: 24711.5234
# Epoch 76/100
#  32/700 [>.............................] - ETA: 0s - loss: 1385265920.0000 - mean_absolute_error: 28217.9805
# Epoch 00076: val_loss did not improve from 1316913163.63636
# 700/700 [==============================] - 0s 73us/sample - loss: 1637074629.4857 - mean_absolute_error: 26245.0547 - val_loss: 1319619130.1818 - val_mean_absolute_error: 24669.3770
# Epoch 77/100
#  32/700 [>.............................] - ETA: 0s - loss: 1085294464.0000 - mean_absolute_error: 22464.1211
# Epoch 00077: val_loss did not improve from 1316913163.63636
# 700/700 [==============================] - 0s 69us/sample - loss: 1543901479.4971 - mean_absolute_error: 25779.6113 - val_loss: 1339537681.4545 - val_mean_absolute_error: 24797.2637
# Epoch 78/100
#  32/700 [>.............................] - ETA: 0s - loss: 1207376768.0000 - mean_absolute_error: 25643.2012
# Epoch 00078: val_loss did not improve from 1316913163.63636
# 700/700 [==============================] - 0s 69us/sample - loss: 1546659750.7657 - mean_absolute_error: 25745.2637 - val_loss: 1523353716.3636 - val_mean_absolute_error: 27239.6934
# Epoch 79/100
#  32/700 [>.............................] - ETA: 0s - loss: 1527219456.0000 - mean_absolute_error: 28861.8164
# Epoch 00079: val_loss did not improve from 1316913163.63636
# 700/700 [==============================] - 0s 70us/sample - loss: 1562093287.8629 - mean_absolute_error: 26237.6523 - val_loss: 1334998155.6364 - val_mean_absolute_error: 24894.4141
# Epoch 80/100
#  32/700 [>.............................] - ETA: 0s - loss: 1020941824.0000 - mean_absolute_error: 26307.6973
# Epoch 00080: val_loss did not improve from 1316913163.63636
# 700/700 [==============================] - 0s 67us/sample - loss: 1529065445.6686 - mean_absolute_error: 25735.8164 - val_loss: 1363105460.3636 - val_mean_absolute_error: 25446.1191
# Epoch 81/100
#  32/700 [>.............................] - ETA: 0s - loss: 670909568.0000 - mean_absolute_error: 19725.4648
# Epoch 00081: val_loss did not improve from 1316913163.63636
# 700/700 [==============================] - 0s 68us/sample - loss: 1546634124.4343 - mean_absolute_error: 26545.3262 - val_loss: 1328362216.7273 - val_mean_absolute_error: 24654.1680
# Epoch 82/100
#  32/700 [>.............................] - ETA: 0s - loss: 5598296576.0000 - mean_absolute_error: 38888.0781
# Epoch 00082: val_loss improved from 1316913163.63636 to 1310842693.81818, saving model to Weights-082--1310842693.81818.hdf5
# 700/700 [==============================] - 0s 112us/sample - loss: 1562310221.8971 - mean_absolute_error: 25940.2031 - val_loss: 1310842693.8182 - val_mean_absolute_error: 24607.7188
# Epoch 83/100
#  32/700 [>.............................] - ETA: 0s - loss: 1407865472.0000 - mean_absolute_error: 23178.2051
# Epoch 00083: val_loss did not improve from 1310842693.81818
# 700/700 [==============================] - 0s 70us/sample - loss: 1513676354.9257 - mean_absolute_error: 26069.5293 - val_loss: 1347083223.2727 - val_mean_absolute_error: 25163.1113
# Epoch 84/100
#  32/700 [>.............................] - ETA: 0s - loss: 667215616.0000 - mean_absolute_error: 20907.2012
# Epoch 00084: val_loss did not improve from 1310842693.81818
# 700/700 [==============================] - 0s 66us/sample - loss: 1486705451.1543 - mean_absolute_error: 25575.3594 - val_loss: 1380107124.3636 - val_mean_absolute_error: 25537.0020
# Epoch 85/100
#  32/700 [>.............................] - ETA: 0s - loss: 1141591680.0000 - mean_absolute_error: 27336.2129
# Epoch 00085: val_loss did not improve from 1310842693.81818
# 700/700 [==============================] - 0s 69us/sample - loss: 1648429556.2971 - mean_absolute_error: 26848.9453 - val_loss: 1362127848.7273 - val_mean_absolute_error: 24800.8301
# Epoch 86/100
#  32/700 [>.............................] - ETA: 0s - loss: 768399744.0000 - mean_absolute_error: 21502.1797
# Epoch 00086: val_loss did not improve from 1310842693.81818
# 700/700 [==============================] - 0s 69us/sample - loss: 1553090599.8629 - mean_absolute_error: 26000.4375 - val_loss: 1403516800.0000 - val_mean_absolute_error: 26035.0762
# Epoch 87/100
#  32/700 [>.............................] - ETA: 0s - loss: 1714550528.0000 - mean_absolute_error: 30859.7461
# Epoch 00087: val_loss did not improve from 1310842693.81818
# 700/700 [==============================] - 0s 68us/sample - loss: 1539395541.2114 - mean_absolute_error: 26035.8887 - val_loss: 1313846842.1818 - val_mean_absolute_error: 24689.4512
# Epoch 88/100
#  32/700 [>.............................] - ETA: 0s - loss: 738586880.0000 - mean_absolute_error: 20012.7695
# Epoch 00088: val_loss did not improve from 1310842693.81818
# 700/700 [==============================] - 0s 68us/sample - loss: 1506760296.5943 - mean_absolute_error: 25672.0996 - val_loss: 1450841652.3636 - val_mean_absolute_error: 26352.5254
# Epoch 89/100
#  32/700 [>.............................] - ETA: 0s - loss: 3227033856.0000 - mean_absolute_error: 32990.8594
# Epoch 00089: val_loss improved from 1310842693.81818 to 1292670080.00000, saving model to Weights-089--1292670080.00000.hdf5
# 700/700 [==============================] - 0s 109us/sample - loss: 1536840509.8057 - mean_absolute_error: 25823.4336 - val_loss: 1292670080.0000 - val_mean_absolute_error: 24522.4141
# Epoch 90/100
#  32/700 [>.............................] - ETA: 0s - loss: 2380924416.0000 - mean_absolute_error: 27651.7773
# Epoch 00090: val_loss did not improve from 1292670080.00000
# 700/700 [==============================] - 0s 70us/sample - loss: 1513490988.9829 - mean_absolute_error: 25973.6973 - val_loss: 1309380788.3636 - val_mean_absolute_error: 24632.2617
# Epoch 91/100
#  32/700 [>.............................] - ETA: 0s - loss: 510173632.0000 - mean_absolute_error: 17420.9023
# Epoch 00091: val_loss did not improve from 1292670080.00000
# 700/700 [==============================] - 0s 71us/sample - loss: 1570432127.2686 - mean_absolute_error: 26050.6934 - val_loss: 1307619776.0000 - val_mean_absolute_error: 24568.1621
# Epoch 92/100
#  32/700 [>.............................] - ETA: 0s - loss: 1026626944.0000 - mean_absolute_error: 24633.7559
# Epoch 00092: val_loss did not improve from 1292670080.00000
# 700/700 [==============================] - 0s 68us/sample - loss: 1479302538.9714 - mean_absolute_error: 25318.7363 - val_loss: 1306250269.0909 - val_mean_absolute_error: 24592.8379
# Epoch 93/100
#  32/700 [>.............................] - ETA: 0s - loss: 809002496.0000 - mean_absolute_error: 19968.0547
# Epoch 00093: val_loss did not improve from 1292670080.00000
# 700/700 [==============================] - 0s 67us/sample - loss: 1515386406.0343 - mean_absolute_error: 25410.1914 - val_loss: 1344332491.6364 - val_mean_absolute_error: 24900.6797
# Epoch 94/100
#  32/700 [>.............................] - ETA: 0s - loss: 782111872.0000 - mean_absolute_error: 21473.5078
# Epoch 00094: val_loss did not improve from 1292670080.00000
# 700/700 [==============================] - 0s 72us/sample - loss: 1520944581.4857 - mean_absolute_error: 25284.4551 - val_loss: 1407856337.4545 - val_mean_absolute_error: 25702.0000
# Epoch 95/100
#  32/700 [>.............................] - ETA: 0s - loss: 408097120.0000 - mean_absolute_error: 14447.1729
# Epoch 00095: val_loss did not improve from 1292670080.00000
# 700/700 [==============================] - 0s 72us/sample - loss: 1538321406.5371 - mean_absolute_error: 25927.7578 - val_loss: 1297497617.4545 - val_mean_absolute_error: 24678.5508
# Epoch 96/100
#  32/700 [>.............................] - ETA: 0s - loss: 1591976448.0000 - mean_absolute_error: 25253.1074
# Epoch 00096: val_loss did not improve from 1292670080.00000
# 700/700 [==============================] - 0s 66us/sample - loss: 1461661370.5143 - mean_absolute_error: 25051.4316 - val_loss: 1312171496.7273 - val_mean_absolute_error: 24675.2891
# Epoch 97/100
#  32/700 [>.............................] - ETA: 0s - loss: 841727296.0000 - mean_absolute_error: 21984.5312
# Epoch 00097: val_loss did not improve from 1292670080.00000
# 700/700 [==============================] - 0s 73us/sample - loss: 1536749497.7829 - mean_absolute_error: 26085.8535 - val_loss: 1356325992.7273 - val_mean_absolute_error: 25519.6074
# Epoch 98/100
#  32/700 [>.............................] - ETA: 0s - loss: 1172858112.0000 - mean_absolute_error: 23554.8145
# Epoch 00098: val_loss did not improve from 1292670080.00000
# 700/700 [==============================] - 0s 72us/sample - loss: 1491566279.3143 - mean_absolute_error: 25233.6562 - val_loss: 1402627618.9091 - val_mean_absolute_error: 25898.0547
# Epoch 99/100
#  32/700 [>.............................] - ETA: 0s - loss: 1342391680.0000 - mean_absolute_error: 26543.2656
# Epoch 00099: val_loss did not improve from 1292670080.00000
# 700/700 [==============================] - 0s 67us/sample - loss: 1482349269.5771 - mean_absolute_error: 25377.4941 - val_loss: 1318063586.9091 - val_mean_absolute_error: 24637.4980
# Epoch 100/100
#  32/700 [>.............................] - ETA: 0s - loss: 1280594176.0000 - mean_absolute_error: 24190.9121
# Epoch 00100: val_loss did not improve from 1292670080.00000
# 700/700 [==============================] - 0s 76us/sample - loss: 1529474674.8343 - mean_absolute_error: 25373.4766 - val_loss: 1300697536.0000 - val_mean_absolute_error: 24431.0547

# %% [markdown]
# ### Inspect errors, epoch after epoch

# %%
# Retrieve the hitory of every epoch's training
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
#             loss  mean_absolute_error      val_loss  val_mean_absolute_error  \
# 95  1.461661e+09         25051.431641  1.312171e+09             24675.289062
# 96  1.536749e+09         26085.853516  1.356326e+09             25519.607422
# 97  1.491566e+09         25233.656250  1.402628e+09             25898.054688
# 98  1.482349e+09         25377.494141  1.318064e+09             24637.498047
# 99  1.529475e+09         25373.476562  1.300698e+09             24431.054688
#
#     epoch
# 95     95
# 96     96
# 97     97
# 98     98
# 99     99

# %%
# Plot the evolution of errors epoch after epoch
plotter = tfdocs.plots.HistoryPlotter(smoothing_std=2)
plotter.plot({'Basic': history}, metric = "mean_absolute_error")
plt.ylabel('MAE')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # 3. Test the Neural Network
# First we instantiate the model using the bext parameters from the training phase.

# %%
#!# Check best checkpoint in your local folder (the last file saved)
#   Paste the name of the last file saved by tech checkpoint system
weights_file = 'Weights-100--1266909282.90909.hdf5' 

# Load teh parameters of teh models (weights & bias)
NN_model.load_weights(weights_file)
NN_model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_squared_error'])

# %%
prediction = NN_model.predict(test)

# %%
plt.figure()
plt.scatter(prediction, truth, alpha=0.2)
plt.xlabel('Predictions')
plt.ylabel('True Values')
lims = [0, 800000]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
error = prediction - truth.to_numpy()
plt.figure()
plt.hist(error[0], bins = 30)
plt.xlabel("Prediction Error")
plt.ylabel("Count")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
